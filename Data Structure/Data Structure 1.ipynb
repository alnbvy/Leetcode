# %%
# 217. Contains Duplicate

class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        return False if (len(nums) == len(list(set(nums)))) else True
# Tip: note that True and False start with capital letter

# %%
# 53. Maximum Subarray

class Solution(object):
    def maxSubArray(self, nums):
        mx = nums[0]
        running_sum = nums[0]
        for num in nums[1:]:
            running_sum = max(num,running_sum + num)
            mx = max(running_sum,mx)

        return mx
    
# You skipped the advanced approach of this problem
# Learn the space and time complexity of this problem

# %%
# 1. Two Sum

-- Brute Force
class Solution(object):
    def twoSum(self, nums, target):
        for i in range(len(nums)):
            for j in range(i+1,len(nums)):
                if (nums[i] + nums[j] == target):
                    return [i,j]
- Hashmap
class Solution(object):
    def twoSum(self, nums, target):
        Hashmap = {}
        for i in range(len(nums)):
            Hashmap[nums[i]] = i
        for i in range(len(nums)):
            comp = target - nums[i]
            if (comp in Hashmap.keys() and Hashmap[comp] != i):
                return [i,Hashmap[comp]]
            
# Tip: not equal is != in python not =!
# x in dic.keys() is correct

-- second Hashmap # One for loop
class Solution(object):
    def twoSum(self, nums, target):
        Hashmap = {}
        for i in range(len(nums)):
            comp = target - nums[i]
            if (comp in Hashmap.keys() and Hashmap[comp] != i):
                return [i,Hashmap[comp]]
            Hashmap[nums[i]] = i

# %%
# 88. Merge Sorted Array

class Solution(object):
    def merge(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        for i in range(len(nums2)):
            nums1[m+i] = nums2[i]
        nums1.sort()
        
# The cost of sorting a list of length xxx using a built-in sorting algorithm is O(xlog⁡x). 
# Because in this case we're sorting a list of length m+nm + nm+n, we get a total time complexity of 
# O((n+m)log⁡(n+m)).
# Space complexity: O(n), but it can vary. 
# Most programming languages have a built-in sorting algorithm that uses O(n) space.

-- second solution
class Solution(object):
    def merge(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        nums1_copy = nums1[:m]
        p1 = p2 = 0

        for p in range(m+n):
            if (p2 >= n) or (p1 < m  and nums2[p2] > nums1_copy[p1]):
                nums1[p] = nums1_copy[p1]
                p1 += 1
            else:
                nums1[p] = nums2[p2]
                p2 += 1
# Time complexity: O(n+m).
# Space complexity: O(m).


# I am skipping the Approach 3: Three Pointers (Start From the End).
# studdy this later.

# %%
# 349. Intersection of Two Arrays

class Solution(object):
    def intersection(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        set1 = set(nums1)
        set2 = set(nums2)
        if (len(set1) < len(set2)):
            return [x for x in set1 if x in set2]
        else:
            return [x for x in set2 if x in set1]
        return lst
    
# Time complexity : O(n+m)
# Space complexity : O(m+n) in the worst case when all elements in the arrays are different.

-- second method
class Solution:
    def intersection(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """  
        set1 = set(nums1)
        set2 = set(nums2)
        return list(set2 & set1)
# Time complexity : O(n+m)
# Space complexity : O(m+n) in the worst case when all elements in the arrays are different.

# %%
# 350. Intersection of Two Arrays II

class Solution(object):
    def intersect(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        Hashmap = {}
        results = []
        if (len(nums1) < len(nums2)):
            for i in nums1:
                Hashmap[i] = nums1.count(i)
            for i in nums2:
                if (i in Hashmap and Hashmap[i] > 0):
                    results.append(i)
                    Hashmap[i] -= 1
            return results
        else:
            for i in nums2:
                Hashmap[i] = nums2.count(i)
            for i in nums1:
                if (i in Hashmap and Hashmap[i] > 0):
                    results.append(i)
                    Hashmap[i] -= 1
            return results  

Time Complexity: O(n+m)   
Space Complexity: O(min⁡(n,m))
----------------------
class Solution(object):
    def intersect(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        if (len(nums1) > len(nums2)): return self.intersect(nums2,nums1)

        Hashmap = {}
        k = 0
        for i in nums1:
            Hashmap[i] = nums1.count(i)
        for i in nums2:
            if (i in Hashmap and Hashmap[i] > 0):
                nums1[k] = i
                Hashmap[i] -= 1
                k += 1
        return nums1[:k]
----------------------
class Solution(object):
    def intersect(self, nums1, nums2):
        if len(nums1) > len(nums2): return self.intersect(nums2, nums1)
            
        cnt = Counter(nums1)
        ans = []
        for x in nums2:
            if cnt[x] > 0:
                ans.append(x)
                cnt[x] -= 1
        return ans
-------------------------
class Solution(object):
    def intersect(self, nums1, nums2):
        from collections import Counter
        c1 = Counter(nums1)
        c2 = Counter(nums2)
        return list((c1&c2).elements())
    
# I skipped the two point approach
# Review how to use Counter

# %%
# 121. Best Time to Buy and Sell Stock

---- Brute force
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        mx = -float('inf')
        for i in range(len(prices)):
            for j in range(i+1,len(prices)):
                if (prices[j] - prices[i] > mx):
                    mx = prices[j] - prices[i]
        return max(mx,0)
Time complexity: O(n^2)
Space: O(1)
    
----------
class Solution(object):
    def maxProfit(self, prices):
        mn = float('inf')
        mx = 0
        for i in range(len(prices)):
            if (prices[i] < mn):
                mn = prices[i]
            elif (prices[i] - mn > mx):
                mx = prices[i] - mn
        return mx
Time complexity: O(n)
Space: O(1)

# %%
# 566. Reshape the Matrix

# Approach 1: Using Queue
class Solution(object):
    def matrixReshape(self, mat, r, c):
        """
        :type mat: List[List[int]]
        :type r: int
        :type c: int
        :rtype: List[List[int]]
        """
        if (r * c != len(mat[0]) * len(mat)):
            return mat
        q = [element for row in mat for element in row]
        return [[q.pop(0) for _ in range(c)] for _ in range(r)]
# Time complexity : O(m⋅n) We traverse over m⋅n elements twice.

# Space complexity : O(m⋅n) The queue formed will be of size m⋅n.

# Tips: 1) learn the double for loop in one line. 2) learn the function .pop 
# 3) If a function returns something it will not proceed anymore.

# Approach 2: Without Using Extra Space
class Solution(object):
    def matrixReshape(self, mat, r, c):
        """
        :type mat: List[List[int]]
        :type r: int
        :type c: int
        :rtype: List[List[int]]
        """
        if (r * c != len(mat[0]) * len(mat)):
            return mat
        row = 0
        col = 0
        res = [[None for _ in range(c)] for _ in range(r)]
        for i in range(len(mat)):
            for j in range(len(mat[0])):
                res[row][col] = mat[i][j]
                col += 1
                if (col == c):
                    col = 0
                    row += 1
        return res
# Time complexity : O(m⋅n) We traverse over m⋅n elements twice.
# Space complexity : O(m⋅n) The queue formed will be of size m⋅n.

# Tips: 1) how to define an empty 2D list

# Approach 3: Using division and modulus
class Solution(object):
    def matrixReshape(self, mat, r, c):
        """
        :type mat: List[List[int]]
        :type r: int
        :type c: int
        :rtype: List[List[int]]
        """
        if (r * c != len(mat[0]) * len(mat)):
            return mat
        cnt = 0
        res = [[None for _ in range(c)] for _ in range(r)]
        for i in range(len(mat)):
            for j in range(len(mat[0])):
                res[cnt // c][cnt%c] = mat[i][j]
                cnt += 1
        return res

# %%
# 118. Pascal's Triangle

class Solution(object):
    def generate(self, numRows):
        """
        :type numRows: int
        :rtype: List[List[int]]
        """
        res = []
        for r in range(numRows):
            row = [None for _ in range(r+1)]
            row[0], row[-1] = 1 , 1
            
            for i in range(1,r):
                row[i] = res[r-1][i-1] + res[r-1][i]
            res.append(row)

        return res
# Time complexity: O(numRows2)
# Space complexity: O(1)
# the input and output generally do not count towards the space complexity.

# %%
# 387. First Unique Character in a String

class Solution(object):
    def firstUniqChar(self, s):
        """
        :type s: str
        :rtype: int
        """
        import collections
        hashmap = collections.Counter(s)
        for idx, ch in enumerate(s):
            if (hashmap[ch] == 1):
                return idx
        return -1
    
# Time complexity : O(N) since we go through the string of length N two times.
# Space complexity : O(1) because English alphabet contains 26 letters.

# Tips: Counter starts with capital C
# Out:
# 3

# %%
# 383. Ransom Note

# Approach 1: Simulation
class Solution(object):
    def canConstruct(self, ransomNote, magazine):
        """
        :type ransomNote: str
        :type magazine: str
        :rtype: bool
        """
        for ch in ransomNote:
            if ch not in magazine:
                return False
            idx = magazine.index(ch)
            # magazine = magazine[:idx] + magazine[idx+1:]
            magazine = magazine.replace(ch,'',1) # TWo methods
        return True
# Time Complexity : O(m⋅n)
# Space Complexity : O(m)
# Tips: 1) Learn how to remove a character from a string 2) ch not in string
------------------------
# Approach 2: Two HashMaps
class Solution(object):
    def canConstruct(self, ransomNote, magazine):
        """
        :type ransomNote: str
        :type magazine: str
        :rtype: bool
        """
        if (len(ransomNote) > len(magazine)):
            return False
        import collections
        r_hash = collections.Counter(ransomNote)
        m_hash = collections.Counter(magazine)
        for cha, cnt in r_hash.items():
            if (cnt > m_hash[cha]):
                return False
        return True
------------------------
# Approach 3: One HashMap
class Solution(object):
    def canConstruct(self, ransomNote, magazine):
        """
        :type ransomNote: str
        :type magazine: str
        :rtype: bool
        """
        if (len(ransomNote) > len(magazine)):
            return False
        import collections
        m_hash = collections.Counter(magazine)
        for cha in ransomNote:
            m_hash[cha] -= 1
            if (m_hash[cha] < 0):
                return False
        return True
------------------------
# Skipping aproach 4

# %%
# 242. Valid Anagram

------------------------
# Approach 1: Sorting
class Solution(object):
    def isAnagram(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        if (len(s) != len(t)):
            return False
        elif (sorted(s) != sorted(t)):
            return False
        else: 
            return True
------------------------
# Approach 2: Hash
class Solution(object):
    def isAnagram(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        import collections
        return collections.Counter(s) == collections.Counter(t)

# %%
# 141. Linked List Cycle
------------------------
# Approach 1: Hash Table
class Solution(object):
    def hasCycle(self, head):
        """
        :type head: ListNode
        :rtype: bool
        """
        st = set()
        while head is not None:
            if head in st:
                return True
            else:
                st.add(head)
                head = head.next
        return False
# Tip: 1) how to initilize an empty set 2) how to add a member to a set
------------------------
# Approach 2: Floyd's Cycle Finding Algorithm
class Solution(object):
    def hasCycle(self, head):
        """
        :type head: ListNode
        :rtype: bool
        """
        if head is None:
            return False
        slow = head
        fast = head.next
        while slow != fast:
            if fast is None or fast.next is None:
                return False
            else:
                slow = slow.next
                fast = fast.next.next
        return True

# %%
# 21. Merge Two Sorted Lists
------------------------
# Approach 1: Recursion
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        if list1 is None:
            return list2
        elif list2 is None :
            return list1
        elif list1.val < list2.val :
            list1.next = self.mergeTwoLists(list1.next,list2)
            return list1
        else:
            list2.next = self.mergeTwoLists(list1,list2.next)
            return list2 
# Tips: 1) elif in python not else if
------------------------
# I skipped the second method. Learn it later.

# %%
# 203. Remove Linked List Elements

class Solution(object):
    def removeElements(self, head, val):
        """
        :type head: ListNode
        :type val: int
        :rtype: ListNode
        """
        sentinel = ListNode(0)
        sentinel.next = head

        prev, curr = sentinel, head
        while curr is not None:
            if (curr.val == val):
                prev.next = curr.next
            else:
                prev = curr
            curr = curr.next
        return sentinel.next
# I did not understand this problem at all. How do we update the values in head or sentinel when they are not
# inside the while loop???????

# %%
# 206. Reverse Linked List

------------------------
# Approach 1: Iterative
class Solution(object):
    def reverseList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        prev = None
        curr = head

        while curr:
            tmp = curr.next
            curr.next = prev
            prev = curr
            curr = tmp
        return prev
------------------------
# Approach 2: Recursive
# I skipped this approach. Study later.

# %%
# 83. Remove Duplicates from Sorted List

# Approach 1: Straight-Forward Approach
class Solution(object):
    def deleteDuplicates(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        tmp = head
        while tmp and tmp.next:
            print(head)
            if tmp.val == tmp.next.val:
                tmp.next = tmp.next.next
            else:
                tmp = tmp.next
        return head
# Tips: when you update tmp.next the head gets updated as well.

# %%
# 20. Valid Parentheses

class Solution(object):
    def isValid(self, s):
        """
        :type s: str
        :rtype: bool
        """
        stack = []
        mapping = {')':'(', ']':'[', '}':'{',}

        for char in s:
            if char in mapping:
                first = stack.pop() if stack else '*'

                if (mapping[char] != first):
                    return False
            else:
                stack.append(char)
        return stack == []
        # return not stack 

# Tips: 1) .pop(index) remove the element from list and returns it as output. the defualt index is -1 (or last)
# 2) return not list will return True if list is empty (or just use list == [])

# %%
# Jumped one stack question

# %%
# 144. Binary Tree Preorder Traversal
------------------------
# Approach 1: Iterations

# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def preorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        if root is None:
            return False
        
        stack = [root]
        out = []

        while stack:
            root = stack.pop()
            if root is not None:
                out.append(root.val)
                if root.right is not None:
                    stack.append(root.right)
                if root.left is not None:
                    stack.append(root.left)  
        return out
# Tips: 1) the correct logical statement: "is not None" not "not None"
# 2) It is important to first append the right root
------------------------
# I skipped the Approach 2: Morris traversal

# %% [markdown]
# ![Tree.png](attachment:Tree.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

------------------------
# Approach 1: Iterations
class Solution(object):
    def inorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        if root is None:
            return []

        stack = []
        out = []
        curr = root

        while True:
            while curr:
                stack.append(curr)
                curr = curr.left
            if not stack:
                return out
            curr = stack.pop()    
            out.append(curr.val)
            curr = curr.right
        return out
# Tips: 1) root == [] won't work!
------------------------
# Approach 2: Recursive Approach
class Solution(object):
    def inorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        self.helper(root,res)
        return res

    def helper(self, root, res):
        if root:
            self.helper(root.left,res)
            res.append(root.val)
            self.helper(root.right,res)
